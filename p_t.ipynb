# %%
import pandas as pd
import numpy as np
import re
import numpy

# %%
df1 = pd.read_csv('final_tagged.csv')
df2 = pd.read_csv('final_df.csv')

# %%
df1
# Out:
#         s.no               tags                  resource  counts  \
# 0          1               name                    సుజాత'       7
# 1          2               type    కాల్పుల విరమణ రేఖ రచన'       7
# 2          3            unknown                       - ō       7
# 3          4       imageSkyline                      _ _'       7
# 4          5         leaderName  శ్రీమతి డేగల భువనేశ్వరి'       7
# ...      ...                ...                       ...     ...
# 10512  10513          eventType      టోక్యో ఒలింపిక్ 2020       1
# 10513  10514             side1a  కాంగ్రెసు అనుబంధ సంస్థలు       1
# 10514  10515  athleticsNickname           ఎంఐటీ ఇంజనీర్లు       1
# 10515  10516         flagborder                     అవును       1
# 10516  10517            causeOf                కోవిడ్ -19       1
#
#                                              resource_id     meta_tags
# 0         <http://te.dbpedia.org/resource/'భీష్మ'_సుజాత>        person
# ...

# %%
df2
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                                  resource
# 0       [' "\\"হ্যাপি\\" ইন গালোসেস হচ্ছে আমেরিকার রক ...
# ...

# %%
df1.drop(['s.no','counts','tags'], axis = 1, inplace = True)

# %%
df1
# Out:
#                        resource  \
# 0                        సుజాత'
# 1        కాల్పుల విరమణ రేఖ రచన'
# 2                           - ō
# 3                          _ _'
# 4      శ్రీమతి డేగల భువనేశ్వరి'
# ...                         ...
# 10512      టోక్యో ఒలింపిక్ 2020
# 10513  కాంగ్రెసు అనుబంధ సంస్థలు
# 10514           ఎంఐటీ ఇంజనీర్లు
# 10515                     అవును
# 10516                కోవిడ్ -19
#
#                                              resource_id     meta_tags
# 0         <http://te.dbpedia.org/resource/'భీష్మ'_సుజాత>        person
# 1      <http://te.dbpedia.org/resource/1949_కరాచీ_ఒప్...          name
# 2      <http://te.dbpedia.org/resource/మిషిమా_యుకియో(...       unknown
# 3      <http://te.dbpedia.org/resource/అంబాబాయి_యోగేశ...       unknown
# 4          <http://te.dbpedia.org/resource/113_తాళ్ళూరు>        person
# ...                                                  ...           ...
# 10512  <http://te.dbpedia.org/resource/శరద్_కుమార్(అథ...          name
# ...

# %%
l1 = df2['resource_id'].to_list()

# %%
# df3 = df1[~numpy.isin(df1['resource_id'], l1)]

# %%
# df3
# Out:
#                                           resource  \
# 92                                          హిందూ'
# 130                                      हैमिल्टन'
# 133                                       కవరట్టి'
# 153                                  బ్నిం మూర్తి'
# 217                       हांगकांग द्वीप यूनाइटेड'
# ...                                            ...
# 10509                       జి ప్రభావతి జి  ప్రసూన
# 10510  గుంజి వెంకట ఐష్వర్య గుంజి వెంకట శ్రీలక్ష్మి
# 10511                                    గుండెపోటు
# 10512                         టోక్యో ఒలింపిక్ 2020
# 10513                     కాంగ్రెసు అనుబంధ సంస్థలు
#
#                                              resource_id     meta_tags
# 92     <http://te.dbpedia.org/resource/Bnim_Murthy_-_...          name
# 130    <http://hi.dbpedia.org/resource/उत्तरी_जिले_क्...      location
# 133             <http://te.dbpedia.org/resource/కవరట్టి>          name
# ...

# %%
df = df1[df1['resource_id'].isin(l1)]

# %%
df
# Out:
#                        resource  \
# 0                        సుజాత'
# 1        కాల్పుల విరమణ రేఖ రచన'
# 2                           - ō
# 3                          _ _'
# 4      శ్రీమతి డేగల భువనేశ్వరి'
# ...                         ...
# 10502                    జీపులు
# 10503    భారత పారాలింపిక్ కమిటీ
# 10514           ఎంఐటీ ఇంజనీర్లు
# 10515                     అవును
# 10516                కోవిడ్ -19
#
#                                              resource_id     meta_tags
# 0         <http://te.dbpedia.org/resource/'భీష్మ'_సుజాత>        person
# 1      <http://te.dbpedia.org/resource/1949_కరాచీ_ఒప్...          name
# 2      <http://te.dbpedia.org/resource/మిషిమా_యుకియో(...       unknown
# 3      <http://te.dbpedia.org/resource/అంబాబాయి_యోగేశ...       unknown
# 4          <http://te.dbpedia.org/resource/113_తాళ్ళూరు>        person
# ...                                                  ...           ...
# 10502  <http://te.dbpedia.org/resource/నిజామాబాద్_పోల...          name
# ...

# %%
l2 = df['resource'].to_list()

# %%
df['res_tag'] = df['resource'] + '_' + df['meta_tags']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4164\1527910154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['res_tag'] = df['resource'] + '_' + df['meta_tags']

# %%
temp_dict = dict(zip(df['resource'], df['res_tag']))

# %%
temp_dict
# Out:
# {"సుజాత'": "సుజాత'_person",
#  "కాల్పుల విరమణ రేఖ రచన'": "కాల్పుల విరమణ రేఖ రచన'_name",
#  '- ō': '- ō_unknown',
#  "_ _'": "_ _'_unknown",
#  "శ్రీమతి డేగల భువనేశ్వరి'": "శ్రీమతి డేగల భువనేశ్వరి'_person",
#  "గద్దె కొండయ్య'": "గద్దె కొండయ్య'_person",
#  "\\ \\ \\ 350 | |  16'": "\\ \\ \\ 350 | |  16'_number",
#  "అంకారా'": "అంకారా'_name",
#  "దేశం'": "దేశం'_name",
#  "紅其拉甫山口'": "紅其拉甫山口'_person",
#  "ఎందుకని'": "ఎందుకని'_name",
#  "−301 ± 1  /'": "−301 ± 1  /'_measure",
#  "కులోత్తుంగ చోళుడు'": "కులోత్తుంగ చోళుడు'_person",
#  "వీరరాజేంద్ర చోళుడు'": "వీరరాజేంద్ర చోళుడు'_person",
#  "జాబితా \\ కిషన్\u200cగడ్ \\ అజ్మీర్ \\ సర్వార్ \\ కేక్రీ \\ పీసాంగన్ \\ నసీరాబాద్ \\ మసుడా \\ బేవార్ \\ భినాయ్'": "జాబితా \\ కిషన్\u200cగడ్ \\ అజ్మీర్ \\ సర్వార్ \\ కేక్రీ \\ పీసాంగన్ \\ నసీరాబాద్ \\ మసుడా \\ బేవార్ \\ భినాయ్'_person",
#  "దక్కను సుల్తానులు'": "దక్కను సుల్తానులు'_name",
#  "布達拉宮'": "布達拉宮'_name",
#  "3  4'": "3  4'_number",
#  "2'": "2'_number",
#  "దుఃఖం'": "దుఃఖం'_name",
# ...

# %%
df3 = df.apply(lambda x: x.replace(temp_dict, regex=True))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df3 = df.apply(lambda x: x.replace(temp_dict, regex=True))
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\apply.py:851, in FrameApply.apply_standard(self)
#     850 def apply_standard(self):
# ...

# %%
for i in l2:
    df6 = df2[df2['resource'].str.contains('|'.join(map(re.escape, i)))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
#       1 for i in l2:
# ----> 2     df6=df2[df2['resource'].str.contains('|'.join(map(re.escape, i)))]
#
# TypeError: 'float' object is not iterable

# %%
for i in l2:
    df6=(df2[[i in x for x in df2['resource']]])
    if df6.empty:
        continue
    print(df6)
#     if [df6 == True]:
#         df6 = df6['resource'].replace(df4['res_tag'])
#     else:
#         None
#     print(df6)

# %%
l3 = list(df['res_tag'])

# %%
l3
# Out:
# ["సుజాత'_person",
#  "కాల్పుల విరమణ రేఖ రచన'_name",
#  '- ō_unknown',
#  "_ _'_unknown",
#  "శ్రీమతి డేగల భువనేశ్వరి'_person",
#  "గద్దె కొండయ్య'_person",
#  "\\ \\ \\ 350 | |  16'_number",
#  "అంకారా'_person",
#  "దేశం'_name",
#  "紅其拉甫山口'_person",
#  "ఎందుకని'_name",
#  "−301 ± 1  /'_number",
#  "కులోత్తుంగ చోళుడు'_person",
#  "వీరరాజేంద్ర చోళుడు'_person",
#  "జాబితా \\ కిషన్\u200cగడ్ \\ అజ్మీర్ \\ సర్వార్ \\ కేక్రీ \\ పీసాంగన్ \\ నసీరాబాద్ \\ మసుడా \\ బేవార్ \\ భినాయ్'_person",
#  "దక్కను సుల్తానులు'_name",
#  "布達拉宮'_name",
#  "3  4'_number",
#  "2'_number",
#  "దుఃఖం'_name",
#  "మహేష్ ఎస్ కోనేరు'_person",
#  "అర్జున్-ప్రసాద్ బ్రదర్స్'_person",
#  "సినిమా పోస్టర్'_name",
#  'দুল-বা মহাবিদ্যালয়"_organization',
#  "భారతదేశం'_location",
#  "\\ ஹி லவ்ஸ் இன் யூ\\'_unknown",
#  "\\ \\'_unknown",
#  "\\  \\'_unknown",
#  "రాజేష్ టచ్ రివర్'_name",
#  "పంచతన్ రికార్డ్ ఇన్'_name",
#  "ఆగష్టు 25  2005'_date",
#  "/ நாள்'_name",
#  "হ্যাঁ'_unknown",
#  "அப்போல்லோ'_name",
# ...

# %%
for j in l3:
    print(j)
# Out:
# సుజాత'_person
# కాల్పుల విరమణ రేఖ రచన'_name
# - ō_unknown
# _ _'_unknown
# శ్రీమతి డేగల భువనేశ్వరి'_person
# గద్దె కొండయ్య'_person
# \ \ \ 350 | |  16'_number
# అంకారా'_person
# దేశం'_name
# 紅其拉甫山口'_person
# ఎందుకని'_name
# −301 ± 1  /'_number
# కులోత్తుంగ చోళుడు'_person
# వీరరాజేంద్ర చోళుడు'_person
# జాబితా \ కిషన్‌గడ్ \ అజ్మీర్ \ సర్వార్ \ కేక్రీ \ పీసాంగన్ \ నసీరాబాద్ \ మసుడా \ బేవార్ \ భినాయ్'_person
# దక్కను సుల్తానులు'_name
# 布達拉宮'_name
# 3  4'_number
# 2'_number
# దుఃఖం'_name
# మహేష్ ఎస్ కోనేరు'_person
# అర్జున్-ప్రసాద్ బ్రదర్స్'_person
# సినిమా పోస్టర్'_name
# দুল-বা মহাবিদ্যালয়"_organization
# భారతదేశం'_location
# \ ஹி லவ்ஸ் இன் யூ\'_unknown
# \ \'_unknown
# \  \'_unknown
# రాజేష్ టచ్ రివర్'_name
# పంచతన్ రికార్డ్ ఇన్'_name
# ఆగష్టు 25  2005'_date
# / நாள்'_name
# হ্যাঁ'_unknown
# அப்போல்லோ'_name
# ஐக்கிய அரபு அமீரகத்தில் மிகவும் புகழ் வாய்ந்தது'_name
# அசென்சன் தீவுடன் தொடர்புடைய அமைப்புகள்'_name
# அசென்சன் தீவு வலையமைப்புத் தகவனிலையம்'_name
# இல்லை'_unknown
# ...

# %%
for i in l2:
    for j in l3:
        m = df2['resource'].str.contains(i)
        df2.loc[m, 'resource'] = df2.loc[m, 'resource'].str.replace( i, j, regex=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
#       2 for j in l3:
#       3     m = df2['resource'].str.contains(i)
# ----> 4     df2.loc[m, 'resource'] = df2.loc[m, 'resource'].str.replace( i, j, regex=True)
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\strings\accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\strings\accessor.py:1435, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1433 # Check whether repl is valid (GH 13438, GH 15055)
# ...

# %%
df2['resource'] = df2['resource'].str.replace(')','')  #-()

# %%
df2['resource'] = df2['resource'].str.replace('"','')
df2['resource'] = df2['resource'].str.replace('"','')
df2['resource'] = df2['resource'].str.replace('(','')
df2['resource'] = df2['resource'].str.replace(')','')
df2['resource'] = df2['resource'].str.replace('[','')
df2['resource'] = df2['resource'].str.replace(',','')
df2['resource'] = df2['resource'].str.replace(']','')
df2['resource'] = df2['resource'].str.replace('\\','')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4164\1922872507.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['resource'] = df2['resource'].str.replace('(','')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4164\1922872507.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['resource'] = df2['resource'].str.replace(')','')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4164\1922872507.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['resource'] = df2['resource'].str.replace('[','')
# ...

# %%
df2.reosurce = df2.resource.str.replace(r"[^a-zA-Z\d\_]+", "")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4164\2790932774.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2.reosurce = df2.resource.str.replace(r"[^a-zA-Z\d\_]+", "")
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4164\2790932774.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df2.reosurce = df2.resource.str.replace(r"[^a-zA-Z\d\_]+", "")

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–"]
for char in spec_chars:
    df2['resource'] = df2['resource'].str.replace(char, ' ')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4164\4175358466.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['resource'] = df2['resource'].str.replace(char, ' ')

# %%
# splitting each resource using whitespaces and re-joining the words again using join.
# df2['resource'] = df2['resource'].str.split().str.join(" ")

# %%
# regexPart1 = r"\s"
# regexPart2 = r"(?:s|'s|!+|,|\.|;|:|\(|\)|\"|\?+)?\s"  
# df2 = re.compile(regexPart1 + re.escape(df2['resource']) + regexPart2 , re.IGNORECASE)
df2['new'] = df2['resource'].apply(lambda x: re.escape(x))
df2 = re.compile('|'.join(df2['resource']))
for i in l2:
    for j in l3:
        m = df2['resource'].str.contains(i)
        df2.loc[m, 'resource'] = df2.loc[m, 'resource'].str.replace( i, j, regex=True)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception

# %%
# for i in l2:
#     for j in l3:
#         df2.loc['resource'] = df2.loc['resource'].str.replace( i , j, regex=True)

# %%
# l2

# %%
df5 = df2.loc[df2['resource'].isin(l2)]

# %%
df5

# %%
temp_dict1

# %%
for i in l2:
#     print(i)
    if [df2['resource'].str.contains(i)]:
        df6 = df2['resource'].str.contains(i).replace(temp_dict_1)
    else:
        df2

# %%
for i in l3:
    df3 = df2.loc[df2['resource'] == i]

# %%
df

# %%
df['re_tag']  = df['resource_id'] + '_' + df['meta_tags']

# %%
l4 = df['re_tag'].to_list()

# %%
l4

# %%
contains_filter = '|'.join(str(l3))
if [df2.resource.str.contains(contains_filter)]:
    for i in l4:
        df2['new'] = df2['resource'].replace(contains_filter, i , inplace = True)

# %%
df2

# %%
l3

# %%
s = df2['resource'].str.split(',',expand=True).stack().str.strip()
df_filter = df2.loc[s[s.isin(l3)]]

# %%
df_filter

# %%
d = dict(zip(df['resource'], df['meta_tags']))

# %%
d
