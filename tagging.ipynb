# %%
import pandas as pd

# %%
# loading dataframes
# df1 = pd.read_csv('tagged_df.csv')
# df2 = pd.read_csv('final.csv')

# %%
df1 = pd.read_csv('final_tagged.csv')
# df2 = pd.read_csv('final_df.csv') 
df2 = pd.read_csv('abstract_master.csv')

# %%
df1.drop(['s.no','tags','counts'], axis=1, inplace = True)

# %%
df1
# Out:
#                        resource  \
# 0                        సుజాత'
# 1        కాల్పుల విరమణ రేఖ రచన'
# 2                           - ō
# 3                          _ _'
# 4      శ్రీమతి డేగల భువనేశ్వరి'
# ...                         ...
# 10512      టోక్యో ఒలింపిక్ 2020
# 10513  కాంగ్రెసు అనుబంధ సంస్థలు
# 10514           ఎంఐటీ ఇంజనీర్లు
# 10515                     అవును
# 10516                కోవిడ్ -19
#
#                                              resource_id     meta_tags
# 0         <http://te.dbpedia.org/resource/'భీష్మ'_సుజాత>        person
# 1      <http://te.dbpedia.org/resource/1949_కరాచీ_ఒప్...          name
# 2      <http://te.dbpedia.org/resource/మిషిమా_యుకియో(...       unknown
# 3      <http://te.dbpedia.org/resource/అంబాబాయి_యోగేశ...       unknown
# 4          <http://te.dbpedia.org/resource/113_తాళ్ళూరు>        person
# ...                                                  ...           ...
# 10512  <http://te.dbpedia.org/resource/శరద్_కుమార్(అథ...          name
# ...

# %%
df2
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                            short_abstract
# 0       [' "\\"হ্যাপি\\" ইন গালোসেস হচ্ছে আমেরিকার রক ...
# ...

# %%
# ## working but not proper
# ls = df2['resource_id'].to_list()
# empty_list = []
# # for values in df1:
# #     print(values)
# for i in ls:
#     t_df = df1.loc[(df1['resource_id'] == i)]
#     empty_list.append(t_df)

# #     t_df = df1.loc[df1['resource_id'] == i]
# #     type(t_df)

# %%
# ls = df2['resource_id'].to_list()
# new_list = []
# for index,row in df1.iterrows():
#     for j in ls:
#         if row['resource_id'] == j:
#             new_list.append(row)
#         else:
#             None

# %%
# d = pd.DataFrame(new_list)

# %%
# # working yet not proper
# ls = df2['resource_id'].to_list()
# temp_df = pd.DataFrame()  ##create a empty list(optional)
# for i in ls:
#     value = df1['resource_id'] == i
# #     print(type(df))
#     if df.empty:
#         continue
#     temp_df.append(value)

# %%
## list for resource_id column in df2
ls = df2['resource_id'].to_list()

# %%
# working script
df = df1[df1['resource_id'].isin(ls)]

# %%
df
# Out:
#                        resource  \
# 0                        సుజాత'
# 1        కాల్పుల విరమణ రేఖ రచన'
# 2                           - ō
# 3                          _ _'
# 4      శ్రీమతి డేగల భువనేశ్వరి'
# ...                         ...
# 10502                    జీపులు
# 10503    భారత పారాలింపిక్ కమిటీ
# 10514           ఎంఐటీ ఇంజనీర్లు
# 10515                     అవును
# 10516                కోవిడ్ -19
#
#                                              resource_id     meta_tags
# 0         <http://te.dbpedia.org/resource/'భీష్మ'_సుజాత>        person
# 1      <http://te.dbpedia.org/resource/1949_కరాచీ_ఒప్...          name
# 2      <http://te.dbpedia.org/resource/మిషిమా_యుకియో(...       unknown
# 3      <http://te.dbpedia.org/resource/అంబాబాయి_యోగేశ...       unknown
# 4          <http://te.dbpedia.org/resource/113_తాళ్ళూరు>        person
# ...                                                  ...           ...
# 10502  <http://te.dbpedia.org/resource/నిజామాబాద్_పోల...          name
# ...

# %%
df.to_csv('sample.csv')

# %% [markdown]
# # pre-processing dataframe 2

# %%
df2['short_abstract'] = df2['short_abstract'].str.replace('"','')
df2['short_abstract'] = df2['short_abstract'].str.replace('"','')
df2['short_abstract'] = df2['short_abstract'].str.replace('(','')
df2['short_abstract'] = df2['short_abstract'].str.replace(')','')
df2['short_abstract'] = df2['short_abstract'].str.replace('[','')
df2['short_abstract'] = df2['short_abstract'].str.replace(',','')
df2['short_abstract'] = df2['short_abstract'].str.replace(']','')
df2['short_abstract'] = df2['short_abstract'].str.replace('\\','')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9144\3698015232.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['short_abstract'] = df2['short_abstract'].str.replace('(','')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9144\3698015232.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['short_abstract'] = df2['short_abstract'].str.replace(')','')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9144\3698015232.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
df2
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                            short_abstract
# 0       ' হ্যাপি ইন গালোসেস হচ্ছে আমেরিকার রক গায়ক স্...
# ...

# %%
df['resource'] = df['resource'].str.replace('"','')
df['resource'] = df['resource'].str.replace('"','')
df['resource'] = df['resource'].str.replace('(','')
df['resource'] = df['resource'].str.replace(')','')
df['resource'] = df['resource'].str.replace('[','')
df['resource'] = df['resource'].str.replace(',','')
df['resource'] = df['resource'].str.replace(']','')
df['resource'] = df['resource'].str.replace('\\','')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9144\1896291746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['resource'] = df['resource'].str.replace('"','')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9144\1896291746.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['resource'] = df['resource'].str.replace('"','')
# ...

# %%
df
# Out:
#                        resource  \
# 0                        సుజాత'
# 1        కాల్పుల విరమణ రేఖ రచన'
# 2                           - ō
# 3                          _ _'
# 4      శ్రీమతి డేగల భువనేశ్వరి'
# ...                         ...
# 10502                    జీపులు
# 10503    భారత పారాలింపిక్ కమిటీ
# 10514           ఎంఐటీ ఇంజనీర్లు
# 10515                     అవును
# 10516                కోవిడ్ -19
#
#                                              resource_id     meta_tags
# 0         <http://te.dbpedia.org/resource/'భీష్మ'_సుజాత>        person
# 1      <http://te.dbpedia.org/resource/1949_కరాచీ_ఒప్...          name
# 2      <http://te.dbpedia.org/resource/మిషిమా_యుకియో(...       unknown
# 3      <http://te.dbpedia.org/resource/అంబాబాయి_యోగేశ...       unknown
# 4          <http://te.dbpedia.org/resource/113_తాళ్ళూరు>        person
# ...                                                  ...           ...
# 10502  <http://te.dbpedia.org/resource/నిజామాబాద్_పోల...          name
# ...

# %%
new_dict = dict(zip(df['resource'], df['resource'] + '_' + df['meta_tags']))

# %%
new_dict
# Out:
# {"సుజాత'": "సుజాత'_person",
#  "కాల్పుల విరమణ రేఖ రచన'": "కాల్పుల విరమణ రేఖ రచన'_name",
#  '- ō': '- ō_unknown',
#  "_ _'": "_ _'_unknown",
#  "శ్రీమతి డేగల భువనేశ్వరి'": "శ్రీమతి డేగల భువనేశ్వరి'_person",
#  "గద్దె కొండయ్య'": "గద్దె కొండయ్య'_person",
#  "   350 | |  16'": "   350 | |  16'_number",
#  "అంకారా'": "అంకారా'_name",
#  "దేశం'": "దేశం'_name",
#  "紅其拉甫山口'": "紅其拉甫山口'_person",
#  "ఎందుకని'": "ఎందుకని'_name",
#  "−301 ± 1  /'": "−301 ± 1  /'_measure",
#  "కులోత్తుంగ చోళుడు'": "కులోత్తుంగ చోళుడు'_person",
#  "వీరరాజేంద్ర చోళుడు'": "వీరరాజేంద్ర చోళుడు'_person",
#  "జాబితా  కిషన్\u200cగడ్  అజ్మీర్  సర్వార్  కేక్రీ  పీసాంగన్  నసీరాబాద్  మసుడా  బేవార్  భినాయ్'": "జాబితా  కిషన్\u200cగడ్  అజ్మీర్  సర్వార్  కేక్రీ  పీసాంగన్  నసీరాబాద్  మసుడా  బేవార్  భినాయ్'_person",
#  "దక్కను సుల్తానులు'": "దక్కను సుల్తానులు'_name",
#  "布達拉宮'": "布達拉宮'_name",
#  "3  4'": "3  4'_number",
#  "2'": "2'_number",
#  "దుఃఖం'": "దుఃఖం'_name",
#  "మహేష్ ఎస్ కోనేరు'": "మహేష్ ఎస్ కోనేరు'_person",
# ...

# %%
## this should work but it is not working may be there is some issue with the dataframe
df3 = df2.apply(lambda x: x.replace(new_dict, regex = True))  ###re.compile(r"(\s*)+")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 ## this should work but it is not working may be there is some issue with the dataframe
# ----> 2 df3 = df2.apply(lambda x: x.replace(new_dict, regex = True))
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
#    8831     self,
#    8832     func=func,
#    (...)
#    8837     kwargs=kwargs,
#    8838 )
# -> 8839 return op.apply().__finalize__(self, method="apply")
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\apply.py:727, in FrameApply.apply(self)
#     724 elif self.raw:
#     725     return self.apply_raw()
# --> 727 return self.apply_standard()
#
# ...

# %%
ls1 = list(df['resource'])

# %%
ls2 = list(df['meta_tags'])

# %%
ls3 = list(df2['resource'])

# %%
ls1
# Out:
# ["సుజాత'",
#  "కాల్పుల విరమణ రేఖ రచన'",
#  '- ō',
#  "_ _'",
#  "శ్రీమతి డేగల భువనేశ్వరి'",
#  "గద్దె కొండయ్య'",
#  "   350 | |  16'",
#  "అంకారా'",
#  "దేశం'",
#  "紅其拉甫山口'",
#  "ఎందుకని'",
#  "−301 ± 1  /'",
#  "కులోత్తుంగ చోళుడు'",
#  "వీరరాజేంద్ర చోళుడు'",
#  "జాబితా  కిషన్\u200cగడ్  అజ్మీర్  సర్వార్  కేక్రీ  పీసాంగన్  నసీరాబాద్  మసుడా  బేవార్  భినాయ్'",
#  "దక్కను సుల్తానులు'",
#  "布達拉宮'",
#  "3  4'",
#  "2'",
#  "దుఃఖం'",
#  "మహేష్ ఎస్ కోనేరు'",
#  "అర్జున్-ప్రసాద్ బ్రదర్స్'",
#  "సినిమా పోస్టర్'",
#  'দুল-বা মহাবিদ্যালয়',
#  "భారతదేశం'",
#  " ஹி லவ்ஸ் இன் யூ'",
#  " '",
#  "  '",
#  "రాజేష్ టచ్ రివర్'",
#  "పంచతన్ రికార్డ్ ఇన్'",
#  "ఆగష్టు 25  2005'",
#  "/ நாள்'",
#  "হ্যাঁ'",
#  "அப்போல்லோ'",
#  "ஐக்கிய அரபு அமீரகத்தில் மிகவும் புகழ் வாய்ந்தது'",
#  "அசென்சன் தீவுடன் தொடர்புடைய அமைப்புகள்'",
#  "அசென்சன் தீவு வலையமைப்புத் தகவனிலையம்'",
#  "இல்லை'",
#  "యూరోపియన్ సొసైటీ ఆఫ్ రేడియాలజీ'",
#  "కొనసాగుతోంది'",
#  "ప్రామాణికం'",
#  "சமச்சீர் ஆள்களப் பெயர் தடை-முடிவுக் கொள்கை'",
# ...

# %%
###converting the df[resource and meta_tags] columns as a dictionary
temp_dict = dict(zip(df['resource'],df['meta_tags']))

# %%
temp_dict
# Out:
# {"సుజాత'": 'person',
#  "కాల్పుల విరమణ రేఖ రచన'": 'name',
#  '- ō': 'unknown',
#  "_ _'": 'unknown',
#  "శ్రీమతి డేగల భువనేశ్వరి'": 'person',
#  "గద్దె కొండయ్య'": 'person',
#  "   350 | |  16'": 'number',
#  "అంకారా'": 'name',
#  "దేశం'": 'name',
#  "紅其拉甫山口'": 'person',
#  "ఎందుకని'": 'name',
#  "−301 ± 1  /'": 'measure',
#  "కులోత్తుంగ చోళుడు'": 'person',
#  "వీరరాజేంద్ర చోళుడు'": 'person',
#  "జాబితా  కిషన్\u200cగడ్  అజ్మీర్  సర్వార్  కేక్రీ  పీసాంగన్  నసీరాబాద్  మసుడా  బేవార్  భినాయ్'": 'person',
#  "దక్కను సుల్తానులు'": 'name',
#  "布達拉宮'": 'name',
#  "3  4'": 'number',
#  "2'": 'number',
#  "దుఃఖం'": 'name',
#  "మహేష్ ఎస్ కోనేరు'": 'person',
#  "అర్జున్-ప్రసాద్ బ్రదర్స్'": 'person',
#  "సినిమా పోస్టర్'": 'name',
#  'দুল-বা মহাবিদ্যালয়': 'organization',
#  "భారతదేశం'": 'location',
#  " ஹி லவ்ஸ் இன் யூ'": 'unknown',
#  " '": 'unknown',
#  "  '": 'unknown',
#  "రాజేష్ టచ్ రివర్'": 'name',
#  "పంచతన్ రికార్డ్ ఇన్'": 'name',
#  "ఆగష్టు 25  2005'": 'date',
#  "/ நாள்'": 'name',
# ...

# %%
# for i in ls1:
#     df5 = df2.loc[df2.resource.str.contains(i)]
#     print(df5)

# %%
# import numpy
# df3 = df2[~numpy.isin(df2['resource'], ls3)]

# %%
# df3

# %%
df2
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                                  resource
# 0       ' হ্যাপি ইন গালোসেস হচ্ছে আমেরিকার রক গায়ক স্...
# ...

# %%
# df2.to_csv('test1.csv')

# %%
## adding new dataframe column by merging two columns in df 
# df['meta_tags'] = df['resource'].astype(str) + '_' + df['meta_tags']

# %%
## replacing values based on dictionary #this should work but it is not working
df3 = df2.replace({"resource": new_dict}, regex = True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [183], in <cell line: 2>()
#       1 ## replacing values based on dictionary
# ----> 2 df3 = df2.replace({"resource": new_dict}, regex = True)
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\frame.py:5282, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5272 @doc(NDFrame.replace, **_shared_doc_kwargs)
#    5273 def replace(
#    5274     self,
#    (...)
#    5280     method: str | lib.NoDefault = lib.no_default,
#    5281 ):
# -> 5282     return super().replace(
#    5283         to_replace=to_replace,
#    5284         value=value,
#    5285         inplace=inplace,
#    5286         limit=limit,
#    5287         regex=regex,
#    5288         method=method,
#    5289     )
#
# ...

# %%
df3
# Out:
#         Date                                              Event   Cost
# 0  10/2/2011     Music is খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1  10000
# 1  11/2/2011  Poetry গোস-ল__mapping=2ো-ত্সা-বা-গ্ঝোন-নু-দ্পা...   5000
# 2  12/2/2011  Theatre তিব্বতী বৌদ্ধধর্মেরী__mapping=3র্ন্যিং...  15000
# 3  13/2/2011                           Comedy is ওয়াইলি_sucess   2000

# %%
# df3.to_csv('t4.csv')

# %%
# new_map = {str(x): str(k) for k, v in new_dict.items() for x in v}

# %%
df2
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                                  resource
# 0       ' হ্যাপি ইন গালোসেস হচ্ছে আমেরিকার রক গায়ক স্...
# ...

# %%
## str. contain will find the value and overwrite it
# for k,v in new_dict.items():
#     df3 = df2.loc[df2['resource'].str.contains('k'), 'resource']
#     df3.replace(k,v)
#     print(df2)

# %%
## replacing value with the help of dictionary
# df2["resource"] = df2["resource"].apply(lambda x: new_dict.get(x))  ## this results in none meaning there is not a match between the dictionary key and the dataframe column

# %%
## mapping a dictionary to the resource column
# df2["re"] = df2["resource"].map(new_dict)  ## results in NaN (not working)

# %%
new_dict

# %%
df2
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                                  resource   re
# 0       ' হ্যাপি ইন গালোসেস হচ্ছে আমেরিকার রক গায়ক স্...  NaN
# ...

# %% [markdown]
# # checking code

# %%
import pandas as pd

# %%
df = pd.DataFrame({'"Date':['10/2/2011', '11/2/2011', '12/2/2011', '13/2/2011'],
                    'Event':['Music is খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা', 'Poetry গোস-লো-ত্সা-বা-গ্ঝোন-নু-দ্পাল love', 'Theatre তিব্বতী বৌদ্ধধর্মের র্ন্যিং-মা ধর্মসম্প্রদায়ের emotion', 'Comedy is ওয়াইলি'],
                   'Cost':[10000, 5000, 15000, 2000]})

# %%
df
# Out:
#        "Date                                              Event   Cost
# 0  10/2/2011               Music is খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা  10000
# 1  11/2/2011          Poetry গোস-লো-ত্সা-বা-গ্ঝোন-নু-দ্পাল love   5000
# 2  12/2/2011  Theatre তিব্বতী বৌদ্ধধর্মের র্ন্যিং-মা ধর্মসম্...  15000
# 3  13/2/2011                                  Comedy is ওয়াইলি   2000

# %%
d = {"খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা":"খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1","গোস-ল":"গোস-ল__mapping=2","তিব্বতী বৌদ্ধধর্মের ":"তিব্বতী বৌদ্ধধর্মেরী__mapping=3","ধর্মসম্প্রদায়ের":"ধর্মসম্প্রদায়ের_mapping=4", "ওয়াইলি":"ওয়াইলি_sucess"}

# %%
# d2 = [{'Name': 'Music', 'Age': 18, 'Marks': 20},
#          {'Name': 'emotion',  'Age': 19, 'Marks': 25},
#          {'Name': 'happy',  'Age': 18,  'Marks': 39 }]

# %%
# df2 = pd.DataFrame(d2)

# %%
# df2

# %%
# df["check"] = df["Event"].map(d)  ##not working

# %%
# df["new"] = df["Event"].apply(lambda x: d.get(x)) ##not working

# %%
# df.drop(['n'], axis= 1, inplace = True) ##not working

# %%
# df['n'] = df.replace({"Event": d}, inplace = True) ##not working

# %%
# df

# %%
d
# Out:
# {'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা': 'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1',
#  'গোস-ল': 'গোস-ল__mapping=2',
#  'তিব্বতী বৌদ্ধধর্মের ': 'তিব্বতী বৌদ্ধধর্মেরী__mapping=3',
#  'ধর্মসম্প্রদায়ের': 'ধর্মসম্প্রদায়ের_mapping=4',
#  'ওয়াইলি': 'ওয়াইলি_sucess'}

# %%
## working ##
for i in d:
    df5 = df.loc[df.Event.str.contains(i)]
    print(df5)
# Out:
#        "Date                                 Event   Cost
# 0  10/2/2011  Music is খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা  10000
#        "Date                                      Event  Cost
# 1  11/2/2011  Poetry গোস-লো-ত্সা-বা-গ্ঝোন-নু-দ্পাল love  5000
#        "Date                                              Event   Cost
# 2  12/2/2011  Theatre তিব্বতী বৌদ্ধধর্মের র্ন্যিং-মা ধর্মসম্...  15000
#        "Date                                              Event   Cost
# 2  12/2/2011  Theatre তিব্বতী বৌদ্ধধর্মের র্ন্যিং-মা ধর্মসম্...  15000
#        "Date              Event  Cost
# 3  13/2/2011  Comedy is ওয়াইলি  2000

# %%
df
# Out:
#        "Date                                              Event   Cost
# 0  10/2/2011               Music is খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা  10000
# 1  11/2/2011          Poetry গোস-লো-ত্সা-বা-গ্ঝোন-নু-দ্পাল love   5000
# 2  12/2/2011  Theatre তিব্বতী বৌদ্ধধর্মের র্ন্যিং-মা ধর্মসম্...  15000
# 3  13/2/2011                                  Comedy is ওয়াইলি   2000

# %%
import numpy
df4 = df[~numpy.isin(df['Event'], d)]

# %%
df4
# Out:
#        "Date                                              Event   Cost
# 0  10/2/2011               Music is খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা  10000
# 1  11/2/2011          Poetry গোস-লো-ত্সা-বা-গ্ঝোন-নু-দ্পাল love   5000
# 2  12/2/2011  Theatre তিব্বতী বৌদ্ধধর্মের র্ন্যিং-মা ধর্মসম্...  15000
# 3  13/2/2011                                  Comedy is ওয়াইলি   2000

# %%
# l1 = list(df2['Name'])

# %%
# for i in l1:
#     df3 = df.loc[df['Event'] == i]
#     print(df3)

# %%
# df.Event.isin(l1).astype(str)

# %%
# for i in l1:
#     if i in df.Event:
#         print(i)
#     else:
#         print('no')

# %%
l1 = list(d.keys())

# %%
l1
# Out:
# ['খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা',
#  'গোস-ল',
#  'তিব্বতী বৌদ্ধধর্মের ',
#  'ধর্মসম্প্রদায়ের',
#  'ওয়াইলি']

# %%
pattern = '|'.join(l1)

# %%
pattern
# Out:
# 'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা|গোস-ল|তিব্বতী বৌদ্ধধর্মের |ধর্মসম্প্রদায়ের|ওয়াইলি'

# %%
n = df.Event.str.contains(pattern)

# %%
n
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# Name: Event, dtype: bool

# %%
# if [n==True]:
#     df['n'] = df['Event'] + '_' + df['Name']
# else:
#     None

# %%
df
# Out:
#        "Date                                              Event   Cost
# 0  10/2/2011               Music is খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা  10000
# 1  11/2/2011          Poetry গোস-লো-ত্সা-বা-গ্ঝোন-নু-দ্পাল love   5000
# 2  12/2/2011  Theatre তিব্বতী বৌদ্ধধর্মের র্ন্যিং-মা ধর্মসম্...  15000
# 3  13/2/2011                                  Comedy is ওয়াইলি   2000

# %%
d
# Out:
# {'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা': 'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1',
#  'গোস-ল': 'গোস-ল__mapping=2',
#  'তিব্বতী বৌদ্ধধর্মের ': 'তিব্বতী বৌদ্ধধর্মেরী__mapping=3',
#  'ধর্মসম্প্রদায়ের': 'ধর্মসম্প্রদায়ের_mapping=4',
#  'ওয়াইলি': 'ওয়াইলি_sucess'}

# %%
if [n == True]:
    print(n)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# Name: Event, dtype: bool

# %%
# ## partially
# def dealer_replace(d, text):
#     regex = re.compile("(%s)" % "|".join(map(re.escape, d.keys())))
#     if regex.search(text):
#         ret = regex.search(text)
#         return d[ret.group()] 
#     else:
#         return text

# %%
# r = re.sub(""(%s)","", l1)

# %%
d
# Out:
# {'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা': 'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1',
#  'গোস-ল': 'গোস-ল__mapping=2',
#  'তিব্বতী বৌদ্ধধর্মের ': 'তিব্বতী বৌদ্ধধর্মেরী__mapping=3',
#  'ধর্মসম্প্রদায়ের': 'ধর্মসম্প্রদায়ের_mapping=4',
#  'ওয়াইলি': 'ওয়াইলি_sucess'}

# %%
import re

# %%
# this is working but not as expected
def dealer_replace(d, text):
    regex = re.compile("(%s)" % "|".join(map(re.escape, d.keys())))
    values = str(d.values())
    
    if regex.search(text):
        ret = regex.search(text)
        return d[ret.group()] 
    else:
        return text

# %%
df['Event'] = df['Event'].apply(lambda v: dealer_replace(d, str(v)))

# %%
df
# Out:
#        "Date                                  Event   Cost
# 0  10/2/2011  খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1  10000
# 1  11/2/2011                       গোস-ল__mapping=2   5000
# 2  12/2/2011        তিব্বতী বৌদ্ধধর্মেরী__mapping=3  15000
# 3  13/2/2011                         ওয়াইলি_sucess   2000

# %%
# df = pd.DataFrame({'Date':['10/2/2011', '11/2/2011', '12/2/2011', '13/2/2011'],
#                     'Event':['Music is good', 'Poetry is love', 'Theatre is an emotion', 'Comedy is happy'],
#                     'Cost':[10000, 5000, 15000, 2000]})

# %%
# s = pd.Series(l1)

# %%
# for i in s:
#     reg = s.str.findall(i)

# %%
# r = re.compile("(%s)+")

# %%
# df.Event.apply(lambda x: bool(r.match(x)))

# %%
# l2 = ['i love music','i hate emotion','i am happy here']

# %%
# ## dont run
# n_li = []
# for i in l1:
#     r = re.compile(i)
#     newlist = list(filter(r.match, df.Event))
#     n_li.append(newlist)

# %%
# for i in l1:
#     r = re.compile("(%s)" % "|".join(i))
#     if r.search(df.Event):
#         ret = r.search(df.Event)
#         print(r)
# #         print(rep)

# %%
# my_lst = ['LAC', 'HOU', '03/03 06:11 PM', '2.13', '1.80', '03/03 03:42 PM']

# subs = {
#          "Houston": "HOU", 
#     "L.A. Clippers": "LAC",
 
#     }
# rev_subs = { v:k for k,v in subs.items()}

# %%
# [rev_subs.get(item,item) for item in my_lst]

# %%
l2 = ['i love music','i hate emotion','i am happy here']

# %%
d1 = {'music_yes':'music','emotion_feeling':'emotion','Theatre_industry':'Theatre','happy_emotion':'happy'}

# %%
## not working
# rev_subs = { v:k for k,v in d1.items()}
# [rev_subs.get(item,item) for item in l2]
# Out:
# ['i love music', 'i hate emotion', 'i am happy here']

# %%
df
# Out:
#         Date                  Event   Cost
# 0  10/2/2011          Music is good  10000
# 1  11/2/2011         Poetry is love   5000
# 2  12/2/2011  Theatre is an emotion  15000
# 3  13/2/2011        Comedy is happy   2000

# %%
# for i in l1:
#     df = df.loc[df['Event'].str.contains(i, case = False)]
#     print(df)
#     if df.empty:
#         continue

# %%
# n_list = []
# for i in l1:
#     out = df[df['Event'].str.contains('|'.join(i))]
#     if [out == True]:
#         df3 = out.Event + df2['Name']
#         n_list.append(df3)
#     else:
#         continue

# %%
# n_list

# %%
# df3 = df[df['Event'].str.contains('|'.join(l1))]

# %%
d
# Out:
# {'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা': 'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1',
#  'গোস-ল': 'গোস-ল__mapping=2',
#  'তিব্বতী বৌদ্ধধর্মের ': 'তিব্বতী বৌদ্ধধর্মেরী__mapping=3',
#  'ধর্মসম্প্রদায়ের': 'ধর্মসম্প্রদায়ের_mapping=4',
#  'ওয়াইলি': 'ওয়াইলি_sucess'}

# %%
df
# Out:
#        "Date                        Event   Cost
# 0  10/2/2011  খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা  10000
# 1  11/2/2011                        গোস-ল   5000
# 2  12/2/2011         তিব্বতী বৌদ্ধধর্মের   15000
# 3  13/2/2011                      ওয়াইলি   2000

# %%
d
# Out:
# {'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা': 'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1',
#  'গোস-ল': 'গোস-ল__mapping=2',
#  'তিব্বতী বৌদ্ধধর্মের ': 'তিব্বতী বৌদ্ধধর্মেরী__mapping=3',
#  'ধর্মসম্প্রদায়ের': 'ধর্মসম্প্রদায়ের_mapping=4',
#  'ওয়াইলি': 'ওয়াইলি_sucess'}

# %%
## workinh properly
df3 = df.apply(lambda x: x.replace(d, regex=True))

# %%
df3
# Out:
#        "Date                                              Event   Cost
# 0  10/2/2011     Music is খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা_mapping=1  10000
# 1  11/2/2011  Poetry গোস-ল__mapping=2ো-ত্সা-বা-গ্ঝোন-নু-দ্পা...   5000
# 2  12/2/2011  Theatre তিব্বতী বৌদ্ধধর্মেরী__mapping=3র্ন্যিং...  15000
# 3  13/2/2011                           Comedy is ওয়াইলি_sucess   2000

# %%
df = pd.read_csv('final_df.csv')

# %%
df
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                                  resource
# 0       [' "\\"হ্যাপি\\" ইন গালোসেস হচ্ছে আমেরিকার রক ...
# ...

# %%
import pandas as pd

t_df1 = pd.read_csv('trail1.csv')
t_df2 = df[1:500]

# %%
t_list = list(t_df2['resource_id'])

# %%
t_list
# Out:
# ['<http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়ার্ল্ড!%22_প্রোগ্রাম>',
#  "<http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছোগ-র্গ্যাল-পো>",
#  "<http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং-গে-র্গ্যাব-পা>",
#  "<http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-বা-গ্ঝোন-নু-দ্পাল>",
#  "<http://bn.dbpedia.org/resource/'গ্যুর-মেদ-কুন-ব্জাং-র্নাম-র্গ্যাল>",
#  "<http://bn.dbpedia.org/resource/'গ্যুর-মেদ-থেগ-ম্ছোগ-ব্স্তান-'দ্জিন>",
#  "<http://bn.dbpedia.org/resource/'গ্যুর-মেদ-ব্দে-ছেন>",
#  "<http://bn.dbpedia.org/resource/'গ্যুর-মেদ-র্নাম-র্গ্যাল_(তিব্বত)>",
#  "<http://bn.dbpedia.org/resource/'গ্রো-ম্গোন-ছোস-র্গ্যাল-'ফাগ্স-পা>",
#  "<http://bn.dbpedia.org/resource/'ছাদ-খা-বা-য়ে-শেস-র্দো-র্জে>",
#  "<http://bn.dbpedia.org/resource/'জা-'ত্শোন-স্ন্যিং-পো>",
#  "<http://bn.dbpedia.org/resource/'জাম-দ্পাল-ত্শুল-খ্রিম্স>",
#  "<http://bn.dbpedia.org/resource/'জাম-দ্পাল-ব্স্কাল-ব্জাং-'জিগ্স-মেদ-ছোস-ক্যি-র্গ্যাল-ম্ত্শান>",
#  "<http://bn.dbpedia.org/resource/'জাম-দ্পাল-রোল-বা'ই-ব্লো-গ্রোস>",
# ...

# %%
t_df1
# Out:
#     s.no            tags                                       resource  \
# 0      1            name                                         సుజాత'
# 1      2            type                         కాల్పుల విరమణ రేఖ రచన'
# 2      3         unknown                                            - ō
# 3      4    imageSkyline                                           _ _'
# 4      5      leaderName                       శ్రీమతి డేగల భువనేశ్వరి'
# ..   ...             ...                                            ...
# 95    96       successor          అంగర కృష్ణారావు  అంగర వెంకటేశ్వరరావు'
# 96    97               d                                         38964'
# 97    98            date                                    జనవరి 2021'
# 98    99           alias                                      అన్నమయ్య'
# 99   100  associatedActs  చంకీలా   అమరజ్యోత్  సురీందర్ సోనియా  మిస్ ఉష'
#
#     counts                                        resource_id meta_tags
# ...

# %%
# working script
t_df = t_df1[t_df1['resource_id'].isin(t_list)]

# %%
t_df
# Out:
#     s.no         tags                    resource  counts  \
# 23    24     colleges        দুল-বা মহাবিদ্যালয়"       1
# 45    46  inTendeduse  অস্তিত্বের সাথে সম্পর্কিত'       1
# 46    47      dnsname                   --54 7 0'       1
# 50    51       primer       ছোট পিস্তল  ম্যাগনাম'       1
#
#                                           resource_id     meta_tags
# 23  <http://bn.dbpedia.org/resource/'ব্রাস-স্পুংস_...  organization
# 45             <http://bn.dbpedia.org/resource/.এফআর>          name
# 46            <http://bn.dbpedia.org/resource/.বাংলা>        number
# 50     <http://bn.dbpedia.org/resource/.৩৫৭_ম্যাগনাম>          name

# %%
t_dict = dict(zip(t_df['resource'], t_df['resource'] + '_' + t_df['meta_tags']))

# %%
t_df2
# Out:
#      Unnamed: 0                                        resource_id  \
# 1             1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2             2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3             3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4             4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# 5             5  <http://bn.dbpedia.org/resource/'গ্যুর-মেদ-কুন...
# ..          ...                                                ...
# 495         495         <http://bn.dbpedia.org/resource/অজিত_রায়>
# 496         496     <http://bn.dbpedia.org/resource/অজিতকুমার_গুহ>
# 497         497  <http://bn.dbpedia.org/resource/অজিতকুমার_চক্র...
# 498         498           <http://bn.dbpedia.org/resource/অজিতনাথ>
# 499         499  <http://bn.dbpedia.org/resource/অজিতেশ_বন্দ্যো...
#
#                                               resource
# 1    [' "হ্যালো ওয়ার্ল্ড! হচ্ছে একটি কম্পিউটার প্র...
# ...

# %%
t_dict
# Out:
# {'দুল-বা মহাবিদ্যালয়"': 'দুল-বা মহাবিদ্যালয়"_organization',
#  "অস্তিত্বের সাথে সম্পর্কিত'": "অস্তিত্বের সাথে সম্পর্কিত'_name",
#  "--54 7 0'": "--54 7 0'_number",
#  "ছোট পিস্তল  ম্যাগনাম'": "ছোট পিস্তল  ম্যাগনাম'_name"}

# %%
l = list(t_df['resource'])

# %%
import re
for i in l:
    subs = i

# %%
temp_list = list(t_df2['resource'])

# %%
res = [x for x in temp_list if re.search(subs, x)]

# %%
res
# Out:
# []

# %%
t_df3 = t_df2.apply(lambda x: x.replace(t_dict, regex = True))

# %%
t_df3.to_csv('test.csv')

# %%
s_df1 = df1.loc[1:1000]
s_df2 = df2.loc[1:1000]

# %%
s_l1 = s_df2['resource_id'].to_list()

# %%
s_df = s_df1[s_df1['resource_id'].isin(s_l1)]

# %%
len(s_df)
# Out:
# 21

# %%
s_dict = dict(zip(s_df['resource'], s_df['resource'] + '_' + s_df['meta_tags']))

# %%
s_dict
# Out:
# {'দুল-বা মহাবিদ্যালয়"': 'দুল-বা মহাবিদ্যালয়"_organization',
#  "অস্তিত্বের সাথে সম্পর্কিত'": "অস্তিত্বের সাথে সম্পর্কিত'_name",
#  "--54 7 0'": "--54 7 0'_number",
#  "ছোট পিস্তল  ম্যাগনাম'": "ছোট পিস্তল  ম্যাগনাম'_name",
#  "নিউক্লিয়ার'": "নিউক্লিয়ার'_name",
#  "সাদা'": "সাদা'_name",
#  "পাতা শ্রীহট্টের_ইতিবৃত্ত_-_উত্তরাংশ /১'": "পাতা শ্রীহট্টের_ইতিবৃত্ত_-_উত্তরাংশ /১'_name",
#  "বৈশাখ সুদ ১৩'": "বৈশাখ সুদ ১৩'_date",
#  "মাহা সুদ ৯'": "মাহা সুদ ৯'_date",
#  "অযোধ্যা'": "অযোধ্যা'_location",
#  "পোষ সুদ ১১'": "পোষ সুদ ১১'_date",
#  "চৈত্র সুদ ৫'": "চৈত্র সুদ ৫'_date",
#  "জিতশত্রু'": "জিতশত্রু'_name",
#  "মহাযক্ষ'": "মহাযক্ষ'_name",
#  "অজিতা'": "অজিতা'_person",
#  "- ü'": "- ü'_unknown",
#  "8370302'": "8370302'_number",
#  "অনসূয়া'": "অনসূয়া'_name",
#  "আলগোনকুইন প্রাদেশিক পার্ক'": "আলগোনকুইন প্রাদেশিক পার্ক'_organization",
#  "অন্নদা সরকারি উচ্চ বিদ্যালয়'": "অন্নদা সরকারি উচ্চ বিদ্যালয়'_organization"}

# %%
s_df3 = s_df2.apply(lambda x: x.replace(s_dict, regex = True))

# %%
s_df3
# Out:
#       Unnamed: 0                                        resource_id  \
# 1              1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2              2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3              3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4              4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# 5              5  <http://bn.dbpedia.org/resource/'গ্যুর-মেদ-কুন...
# ...          ...                                                ...
# 996          996          <http://bn.dbpedia.org/resource/অপরাজিতা>
# 997          997     <http://bn.dbpedia.org/resource/অপরাজিতা_আঢ্য>
# 998          998       <http://bn.dbpedia.org/resource/অপরাজিতা_হক>
# 999          999  <http://bn.dbpedia.org/resource/অপরাজেয়_(চলচ্...
# 1000        1000    <http://bn.dbpedia.org/resource/অপরাজেয়_বাংলা>
#
#                                                resource
# 1     [' "হ্যালো ওয়ার্ল্ড! হচ্ছে একটি কম্পিউটার প্র...
# ...

# %%
s_df3.to_csv('s_df.csv')

# %% [markdown]
# # try

# %%
import pandas as pd

# %%
df1 = pd.read_csv('final_tagged.csv')
df2 = pd.read_csv('final_df.csv')

# %%
df1.drop(['s.no','tags','counts'], axis = 1, inplace = True)

# %%
df
# Out:
#                        resource  \
# 0                        సుజాత'
# 1        కాల్పుల విరమణ రేఖ రచన'
# 2                           - ō
# 3                          _ _'
# 4      శ్రీమతి డేగల భువనేశ్వరి'
# ...                         ...
# 10502                    జీపులు
# 10503    భారత పారాలింపిక్ కమిటీ
# 10514           ఎంఐటీ ఇంజనీర్లు
# 10515                     అవును
# 10516                కోవిడ్ -19
#
#                                              resource_id     meta_tags
# 0         <http://te.dbpedia.org/resource/'భీష్మ'_సుజాత>        person
# 1      <http://te.dbpedia.org/resource/1949_కరాచీ_ఒప్...          name
# 2      <http://te.dbpedia.org/resource/మిషిమా_యుకియో(...       unknown
# 3      <http://te.dbpedia.org/resource/అంబాబాయి_యోగేశ...       unknown
# 4          <http://te.dbpedia.org/resource/113_తాళ్ళూరు>        person
# ...                                                  ...           ...
# 10502  <http://te.dbpedia.org/resource/నిజామాబాద్_పోల...          name
# ...

# %%
l1 = list(df2['resource_id'])

# %%
df = df1[df1['resource_id'].isin(l1)]

# %%
l2 = list(df['resource'])

# %%
l3 = list(df2['resource'])

# %%
d = dict(zip(df['resource'], df['meta_tags']))

# %%
d
# Out:
# {"సుజాత'": 'person',
#  "కాల్పుల విరమణ రేఖ రచన'": 'name',
#  '- ō': 'unknown',
#  "_ _'": 'unknown',
#  "శ్రీమతి డేగల భువనేశ్వరి'": 'person',
#  "గద్దె కొండయ్య'": 'person',
#  "\\ \\ \\ 350 | |  16'": 'number',
#  "అంకారా'": 'name',
#  "దేశం'": 'name',
#  "紅其拉甫山口'": 'person',
#  "ఎందుకని'": 'name',
#  "−301 ± 1  /'": 'measure',
#  "కులోత్తుంగ చోళుడు'": 'person',
#  "వీరరాజేంద్ర చోళుడు'": 'person',
#  "జాబితా \\ కిషన్\u200cగడ్ \\ అజ్మీర్ \\ సర్వార్ \\ కేక్రీ \\ పీసాంగన్ \\ నసీరాబాద్ \\ మసుడా \\ బేవార్ \\ భినాయ్'": 'person',
#  "దక్కను సుల్తానులు'": 'name',
#  "布達拉宮'": 'name',
#  "3  4'": 'number',
#  "2'": 'number',
#  "దుఃఖం'": 'name',
#  "మహేష్ ఎస్ కోనేరు'": 'person',
#  "అర్జున్-ప్రసాద్ బ్రదర్స్'": 'person',
#  "సినిమా పోస్టర్'": 'name',
#  'দুল-বা মহাবিদ্যালয়"': 'organization',
#  "భారతదేశం'": 'location',
#  "\\ ஹி லவ்ஸ் இன் யூ\\'": 'unknown',
#  "\\ \\'": 'unknown',
#  "\\  \\'": 'unknown',
#  "రాజేష్ టచ్ రివర్'": 'name',
#  "పంచతన్ రికార్డ్ ఇన్'": 'name',
# ...

# %%
def replacing(d, text):
    for i in l2:
        regex = re.compile("(%s)" % "|".join(map(re.escape, d.keys())))
        if regex.search(text):
            ret = regex.search(text)
            return d[ret.group()] 
        else:
            return text

# %%
df2['Event'] = df2['resource'].apply(lambda v: l2, str(j))

# %%
def value(text):
    regex = re.compile("(%s)" % "|".join(map(l2)))
    if regex.search(text):
        grp = regex.search(text)
        return grp.group()

# %%
d
# Out:
# {"సుజాత'": 'person',
#  "కాల్పుల విరమణ రేఖ రచన'": 'name',
#  '- ō': 'unknown',
#  "_ _'": 'unknown',
#  "శ్రీమతి డేగల భువనేశ్వరి'": 'person',
#  "గద్దె కొండయ్య'": 'person',
#  "\\ \\ \\ 350 | |  16'": 'number',
#  "అంకారా'": 'name',
#  "దేశం'": 'name',
#  "紅其拉甫山口'": 'person',
#  "ఎందుకని'": 'name',
#  "−301 ± 1  /'": 'measure',
#  "కులోత్తుంగ చోళుడు'": 'person',
#  "వీరరాజేంద్ర చోళుడు'": 'person',
#  "జాబితా \\ కిషన్\u200cగడ్ \\ అజ్మీర్ \\ సర్వార్ \\ కేక్రీ \\ పీసాంగన్ \\ నసీరాబాద్ \\ మసుడా \\ బేవార్ \\ భినాయ్'": 'person',
#  "దక్కను సుల్తానులు'": 'name',
#  "布達拉宮'": 'name',
#  "3  4'": 'number',
#  "2'": 'number',
#  "దుఃఖం'": 'name',
#  "మహేష్ ఎస్ కోనేరు'": 'person',
#  "అర్జున్-ప్రసాద్ బ్రదర్స్'": 'person',
#  "సినిమా పోస్టర్'": 'name',
#  'দুল-বা মহাবিদ্যালয়"': 'organization',
#  "భారతదేశం'": 'location',
#  "\\ ஹி லவ்ஸ் இன் யூ\\'": 'unknown',
#  "\\ \\'": 'unknown',
#  "\\  \\'": 'unknown',
#  "రాజేష్ టచ్ రివర్'": 'name',
#  "పంచతన్ రికార్డ్ ఇన్'": 'name',
# ...

# %%
df['cb'] = df['resource'] + '_' + df['meta_tags']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6440\1854071707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cb'] = df['resource'] + '_' + df['meta_tags']

# %%
df
# Out:
#                        resource  \
# 0                        సుజాత'
# 1        కాల్పుల విరమణ రేఖ రచన'
# 2                           - ō
# 3                          _ _'
# 4      శ్రీమతి డేగల భువనేశ్వరి'
# ...                         ...
# 10502                    జీపులు
# 10503    భారత పారాలింపిక్ కమిటీ
# 10514           ఎంఐటీ ఇంజనీర్లు
# 10515                     అవును
# 10516                కోవిడ్ -19
#
#                                              resource_id     meta_tags  \
# 0         <http://te.dbpedia.org/resource/'భీష్మ'_సుజాత>        person
# 1      <http://te.dbpedia.org/resource/1949_కరాచీ_ఒప్...          name
# 2      <http://te.dbpedia.org/resource/మిషిమా_యుకియో(...       unknown
# 3      <http://te.dbpedia.org/resource/అంబాబాయి_యోగేశ...       unknown
# 4          <http://te.dbpedia.org/resource/113_తాళ్ళూరు>        person
# ...                                                  ...           ...
# 10502  <http://te.dbpedia.org/resource/నిజామాబాద్_పోల...          name
# ...

# %%
l4 = df['cb'].to_list()

# %%
l4
# Out:
# ["సుజాత'_person",
#  "కాల్పుల విరమణ రేఖ రచన'_name",
#  '- ō_unknown',
#  "_ _'_unknown",
#  "శ్రీమతి డేగల భువనేశ్వరి'_person",
#  "గద్దె కొండయ్య'_person",
#  "\\ \\ \\ 350 | |  16'_number",
#  "అంకారా'_person",
#  "దేశం'_name",
#  "紅其拉甫山口'_person",
#  "ఎందుకని'_name",
#  "−301 ± 1  /'_number",
#  "కులోత్తుంగ చోళుడు'_person",
#  "వీరరాజేంద్ర చోళుడు'_person",
#  "జాబితా \\ కిషన్\u200cగడ్ \\ అజ్మీర్ \\ సర్వార్ \\ కేక్రీ \\ పీసాంగన్ \\ నసీరాబాద్ \\ మసుడా \\ బేవార్ \\ భినాయ్'_person",
#  "దక్కను సుల్తానులు'_name",
#  "布達拉宮'_name",
#  "3  4'_number",
#  "2'_number",
#  "దుఃఖం'_name",
#  "మహేష్ ఎస్ కోనేరు'_person",
#  "అర్జున్-ప్రసాద్ బ్రదర్స్'_person",
#  "సినిమా పోస్టర్'_name",
#  'দুল-বা মহাবিদ্যালয়"_organization',
#  "భారతదేశం'_location",
#  "\\ ஹி லவ்ஸ் இன் யூ\\'_unknown",
#  "\\ \\'_unknown",
#  "\\  \\'_unknown",
#  "రాజేష్ టచ్ రివర్'_name",
#  "పంచతన్ రికార్డ్ ఇన్'_name",
#  "ఆగష్టు 25  2005'_date",
#  "/ நாள்'_name",
#  "হ্যাঁ'_unknown",
#  "அப்போல்லோ'_name",
# ...

# %%
def replace(l4, grp):
    for i in l4:
        if grp >= 0:
            rep = grp.replace(i)
        return rep

# %%
res  = re.sub(value, replace,l2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 res  = re.sub(value, replace,l2)
#
# File ~\.conda\envs\jairam\lib\re.py:210, in sub(pattern, repl, string, count, flags)
#     203 def sub(pattern, repl, string, count=0, flags=0):
#     204     """Return the string obtained by replacing the leftmost
#     205     non-overlapping occurrences of the pattern in string by the
#     206     replacement repl.  repl can be either a string or a callable;
#     207     if a string, backslash escapes in it are processed.  If it is
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#
# File ~\.conda\envs\jairam\lib\re.py:303, in _compile(pattern, flags)
#     301     return pattern
# ...

# %%
df2
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                                  resource  \
# 0       [' "\\"হ্যাপি\\" ইন গালোসেস হচ্ছে আমেরিকার রক ...
# ...

# %%
df2
# Out:
#         Unnamed: 0                                        resource_id  \
# 0                0  <http://bn.dbpedia.org/resource/%22হ্যাপি%22_ই...
# 1                1  <http://bn.dbpedia.org/resource/%22হ্যালো,_ওয়...
# 2                2  <http://bn.dbpedia.org/resource/'খোন-দ্কোন-ম্ছ...
# 3                3  <http://bn.dbpedia.org/resource/'খ্রুল-ঝিগ-সেং...
# 4                4  <http://bn.dbpedia.org/resource/'গোস-লো-ত্সা-ব...
# ...            ...                                                ...
# 663407      663407   <http://te.dbpedia.org/resource/ఇన్‌స్టాగ్రామ్‌>
# 663408      663408     <http://te.dbpedia.org/resource/ఆనంద్_ఇస్లామా>
# 663409      663409       <http://te.dbpedia.org/resource/యానం_జిల్లా>
# 663410      663410  <http://te.dbpedia.org/resource/సుషాంత్_సింఘ్_...
# 663411      663411       <http://te.dbpedia.org/resource/Vadde_caste>
#
#                                                  resource Event
# ...

# %%
import re
for j in l3:
    df2['Event'] = df2['resource'].apply(lambda v: replacing(l2, j))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 import re
#       2 for j in l3:
# ----> 3     df2['Event'] = df2['resource'].apply(lambda v: replacing(l2, j))
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\.conda\envs\jairam\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
# ...
